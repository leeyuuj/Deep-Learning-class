# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%bash
# mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace"
# mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/scripts"
# mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/scripts/preprocessing"
# mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo"
# mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/exported-models"
# mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images"
# mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/annotations"
# mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images/test"
# mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images/train"
# mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/models"
# mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/pre-trained-models"

# %%
# !mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/pre-trained-models"
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/pre-trained-models’: File exists

# %%
# !mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images"

# %%
# !pip install -U "tensorflow>=2.5"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 588.3 MB 21 kB/s
# ...
#      |████████████████████████████████| 1.7 MB 92.2 MB/s
# ...
#      |████████████████████████████████| 439 kB 101.3 MB/s
# ...
#      |████████████████████████████████| 6.0 MB 95.7 MB/s
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
# ...

# %%
import os
import pathlib

if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 79836, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 79836 (delta 5), reused 1 (delta 0), pack-reused 79824
# Receiving objects: 100% (79836/79836), 594.04 MiB | 16.60 MiB/s, done.
# Resolving deltas: 100% (56857/56857), done.

# %%
# %%bash
# sudo apt install -y protobuf-compiler
# cd /content/models/research/
# protoc object_detection/protos/*.proto --python_out=.
# cd /content
# git clone https://github.com/cocodataset/cocoapi.git
# cd /content/cocoapi/PythonAPI
# make
# cp -r pycocotools /content/models/research/
# cd /content/models/research/
# cp object_detection/packages/tf2/setup.py .
# python -m pip install .
# cd /content

# %%
# !python /content/models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# 2022-12-19 01:08:21.505390: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-19 01:08:21.651877: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-12-19 01:08:22.462710: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images
# Out:
# /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images

# %%
# !tar -xvf /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/datasets/annotations.tar.gz \
-C "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/train_images/"

# %%
# !rm -r "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images/annotations"

# %%
# !mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/train_images"

# %%
# %cd /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/train_images
# Out:
# /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/train_images

# %%
# !rm -r /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images/annotations

# %%
# %cd /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images
# Out:
# /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images

# %%
# !rm -r /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images/models

# %%
# !tar -xvf /content/drive/MyDrive/Tensorflow_OD_API/datasets/Oxford-pet/annotations.tar.gz
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# annotations/trimaps/._pomeranian_180.png
# annotations/trimaps/pomeranian_180.png
# annotations/trimaps/._pomeranian_181.png
# annotations/trimaps/pomeranian_181.png
# annotations/trimaps/._pomeranian_182.png
# annotations/trimaps/pomeranian_182.png
# annotations/trimaps/._pomeranian_183.png
# annotations/trimaps/pomeranian_183.png
# annotations/trimaps/._pomeranian_184.png
# annotations/trimaps/pomeranian_184.png
# annotations/trimaps/._pomeranian_185.png
# annotations/trimaps/pomeranian_185.png
# annotations/trimaps/._pomeranian_186.png
# annotations/trimaps/pomeranian_186.png
# annotations/trimaps/._pomeranian_187.png
# annotations/trimaps/pomeranian_187.png
# annotations/trimaps/._pomeranian_188.png
# annotations/trimaps/pomeranian_188.png
# annotations/trimaps/._pomeranian_189.png
# annotations/trimaps/pomeranian_189.png
# annotations/trimaps/._pomeranian_19.png
# annotations/trimaps/pomeranian_19.png
# ...

# %%
# %cd /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images
# Out:
# /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images

# %%
# !pwd
# Out:
# /content

# %%
import re
from shutil import copyfile
import argparse
import math
import random

# %%
imageDir = "/content/oxfordpet_images/images"

# %%
images = [f for f in os.listdir(imageDir)
              if re.search(r'([a-zA-Z0-9\s_\\.\-\(\):])+(?i)(.jpg|.jpeg|.png)$', f)]        # 리눅스 정규식 표현 : 파일에 a-z,A-Z,0-9라 적혀있는 파일이면 모두 가져온다.

# %%
num_images = len(images)

# %%
num_images
# Out:
# 7390

# %%
# !pwd
# Out:
# /content

# %%
# !mkdir oxfordpet_images

# %%
# !pwd
# Out:
# /content

# %%
# %cd oxfordpet_images/
# Out:
# /content/oxfordpet_images

# %%
# !pwd
# Out:
# /content/oxfordpet_images

# %%
# !tar -xvf /content/drive/MyDrive/Tensorflow_OD_API/datasets/Oxford-pet/images.tar.gz
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# images/american_bulldog_194.jpg
# images/Birman_175.jpg
# images/american_bulldog_178.jpg
# images/staffordshire_bull_terrier_93.jpg
# images/Egyptian_Mau_58.jpg
# images/havanese_44.jpg
# images/english_cocker_spaniel_97.jpg
# images/Ragdoll_111.jpg
# images/american_pit_bull_terrier_159.jpg
# images/english_setter_134.jpg
# images/english_setter_87.jpg
# images/wheaten_terrier_198.jpg
# images/pug_180.jpg
# images/boxer_172.jpg
# images/Sphynx_197.jpg
# images/german_shorthaired_2.jpg
# images/British_Shorthair_9.jpg
# images/pug_89.jpg
# images/japanese_chin_39.jpg
# images/Ragdoll_20.jpg
# images/american_bulldog_111.jpg
# images/yorkshire_terrier_112.jpg
# images/Persian_88.jpg
# images/pug_9.jpg
# images/Birman_40.jpg
# images/British_Shorthair_272.jpg
# images/havanese_7.jpg
# images/pomeranian_154.jpg
# images/beagle_49.jpg
# images/British_Shorthair_94.jpg
# images/Persian_90.jpg
# images/staffordshire_bull_terrier_30.jpg
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/train_images

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo

# %%
# !ls -al
# Out:
# total 20
# drwx------ 4 root root 4096 Nov 28 02:06 annotations
# drwx------ 2 root root 4096 Nov 28 02:06 exported-models
# drwx------ 3 root root 4096 Nov 28 02:06 models
# drwx------ 2 root root 4096 Nov 28 02:06 pre-trained-models
# drwx------ 4 root root 4096 Dec 16 08:15 train_images

# %%
# !rm -r /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images

# %%
# !rm -r /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images/test

# %%
# !rm -r /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images/train

# %%
# !mv /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/train_images

# %%
# !cp "/content/models/research/object_detection/data/pet_label_map.pbtxt" \
"/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/annotations"

# %%
# !mv "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/annotations/pet_label_map.pbtxt" \
"/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/annotations/label_map.pbtxt"

# %%
# !mkdir /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/annotations/records

# %%
# !rm -r /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/annotations/records

# %%
# !mkdir /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/annotations/records

# %%
# !rm -r /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/annotations/recrods

# %%
# !python /content/models/research/object_detection/dataset_tools/create_pet_tf_record.py \
    --label_map_path="/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/annotations/label_map.pbtxt" \
    --data_dir=/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/images \
    --output_dir=/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/annotations/records

# %%
# %cd /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/pre-trained-models
# Out:
# /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/pre-trained-models

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d1_coco17_tpu-32.tar.gz
# Out:
# --2022-12-18 14:15:18--  http://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d1_coco17_tpu-32.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 172.253.118.128, 2404:6800:4003:c02::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|172.253.118.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 51839363 (49M) [application/x-tar]
# Saving to: ‘efficientdet_d1_coco17_tpu-32.tar.gz’
#
# efficientdet_d1_coc 100%[===================>]  49.44M  61.0MB/s    in 0.8s
#
# 2022-12-18 14:15:19 (61.0 MB/s) - ‘efficientdet_d1_coco17_tpu-32.tar.gz’ saved [51839363/51839363]

# %%
# %cd /content
# Out:
# /content

# %%
# !pwd
# Out:
# /content

# %%
# !tar -xvf /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/pre-trained-models/efficientdet_d1_coco17_tpu-32.tar.gz
# Out:
# efficientdet_d1_coco17_tpu-32/
# efficientdet_d1_coco17_tpu-32/checkpoint/
# efficientdet_d1_coco17_tpu-32/checkpoint/ckpt-0.data-00000-of-00001
# efficientdet_d1_coco17_tpu-32/checkpoint/checkpoint
# efficientdet_d1_coco17_tpu-32/checkpoint/ckpt-0.index
# efficientdet_d1_coco17_tpu-32/pipeline.config
# efficientdet_d1_coco17_tpu-32/saved_model/
# efficientdet_d1_coco17_tpu-32/saved_model/saved_model.pb
# efficientdet_d1_coco17_tpu-32/saved_model/assets/
# efficientdet_d1_coco17_tpu-32/saved_model/variables/
# efficientdet_d1_coco17_tpu-32/saved_model/variables/variables.data-00000-of-00001
# efficientdet_d1_coco17_tpu-32/saved_model/variables/variables.index

# %%
# !mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/models/myft_efficientDet_d1"

# %%
# !cp "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/pre-trained-models/efficientdet_d1_coco17_tpu-32/pipeline.config" \
"/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/models/myft_efficientDet_d1"

# %%
# %cd /content
# Out:
# /content

# %%
# !pwd
# Out:
# /content

# %%
# !python /content/models/research/object_detection/model_main_tf2.py \
--model_dir="/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/models/myft_effDet_new" \
--pipeline_config_path="/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/models/myft_effDet_new/pipeline.config"
# Out:
# 2022-12-19 01:30:33.351972: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-19 01:30:33.497129: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-12-19 01:30:34.348888: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %% [markdown]
# **모델 저장하기**

# %%
# !mkdir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/exported-models/saved_effDet_new"

# %%
# !python /content/models/research/object_detection/exporter_main_v2.py \
--input_type image_tensor \
--pipeline_config_path "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/models/myft_effDet_new/pipeline.config" \
--trained_checkpoint_dir "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/models/myft_effDet_new" \
--output_directory "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/exported-models/saved_effDet_new"
# Out:
# 2022-12-19 05:15:41.338471: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-19 05:15:41.479619: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-12-19 05:15:42.300805: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %% [markdown]
# ---

# %%
# !python /content/models/research/object_detection/model_main_tf2.py \
# --model_dir="/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/exported-models/saved_efficientDet_D2" \
# --pipeline_config_path "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/exported-models/saved_efficientDet_D1/pipeline.config"

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir="/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/models/myft_efficientDet_d1"

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings
import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
# %matplotlib inline

# %%
PATH_TO_MODEL_DIR = "/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/exported-models/saved_effDet_new"
PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"
print(PATH_TO_SAVED_MODEL)
# Out:
# /content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/exported-models/saved_effDet_new/saved_model

# %%
import tensorflow as tf

# %%
print('Loading model...', end='')
start_time = time.time()

# Load saved model and build the detection function
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))
# Out:
# Loading model...Done! Took 36.1404504776001 seconds

# %%
category_index = label_map_util.create_category_index_from_labelmap("/content/drive/MyDrive/Tensorflow_OD_API/EfficientDet_D1_640x640/workspace/training_demo/annotations/label_map.pbtxt",use_display_name=True)

# %%
imageDir2 = "/content/cat"
IMAGE_PATHS = [imageDir2 + "/" + f for f in os.listdir(imageDir2) if f[-4:] in ['.jpg','.jpeg','.png']]
IMAGE_PATHS = IMAGE_PATHS[0:9]

# %%
def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.

    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.

    Args:
      path: the file path to the image

    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))

# %%
for image_path in IMAGE_PATHS:

    print('Running inference for {}... '.format(image_path), end='')

    image_np = load_image_into_numpy_array(image_path)

    # Things to try:
    # Flip horizontally
    # image_np = np.fliplr(image_np).copy()

    # Convert image to grayscale
    # image_np = np.tile(
    #     np.mean(image_np, 2, keepdims=True), (1, 1, 3)).astype(np.uint8)

    # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
    input_tensor = tf.convert_to_tensor(image_np)
    # The model expects a batch of images, so add an axis with `tf.newaxis`.
    input_tensor = input_tensor[tf.newaxis, ...]

    # input_tensor = np.expand_dims(image_np, 0)
    detections = detect_fn(input_tensor)

    # All outputs are batches tensors.
    # Convert to numpy arrays, and take index [0] to remove the batch dimension.
    # We're only interested in the first num_detections.
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy()
                   for key, value in detections.items()}
    detections['num_detections'] = num_detections

    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

    image_np_with_detections = image_np.copy()

    viz_utils.visualize_boxes_and_labels_on_image_array(
          image_np_with_detections,
          detections['detection_boxes'],
          detections['detection_classes'],
          detections['detection_scores'],
          category_index,
          use_normalized_coordinates=True,
          max_boxes_to_draw=200,
          min_score_thresh=.30,
          agnostic_mode=False)

    plt.figure(figsize=(12,12))
    plt.imshow(image_np_with_detections)
    print('Done')
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
